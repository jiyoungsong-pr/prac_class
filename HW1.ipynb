# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyoungsong-pr/prac_class/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
cars %>% summary()
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %% [markdown]
# plot(cars)

# %%
[ ] cars %>% plot()
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:1: unexpected '['
# 1: [
#     ^
# Traceback:

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
flights[1:5,]
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00

# %%
filter(flights, month==1,day==1) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
flights %>% filter(month==1, day==1) %>% filter(dest =='ORD') %>% head
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   608      600             8        807      735
# 4 2013 1     1   629      630            -1        824      810
# 5 2013 1     1   656      700            -4        854      850
# 6 2013 1     1   709      700             9        852      832
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150      719      5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138      733      6     0
# 3 32        MQ      3768   N9EAMQ  EWR    ORD  139      719      6     0
# 4 14        AA       303   N3CYAA  LGA    ORD  140      733      6    30
# 5  4        AA       305   N4WNAA  LGA    ORD  143      733      7     0
# 6 20        UA      1092   N26226  LGA    ORD  135      733      7     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 06:00:00
# 3 2013-01-01 06:00:00
# 4 2013-01-01 06:00:00
# 5 2013-01-01 07:00:00
# 6 2013-01-01 07:00:00

# %%
flights %>% fliter(month == 1 & day== 1 & dest % in% c('ORD','LAS')) %>% head()
# Out:
# Error in fliter(., month == 1 & day == 1 & dest % in% c("ORD", "LAS")): could not find function "fliter"
# Traceback:
#
# 1. flights %>% fliter(month == 1 & day == 1 & dest % in% c("ORD",
#  .     "LAS")) %>% head()
# 2. head(.)

# %%
arrange(flights, year, month, day) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x=displ, y= hwy))
# Out:
# plot without title

# %%
ggplot(data=mpg, mapping =aes(x=displ, y=hwy)) + 
geom_point()+
geom_line()
# Out:
# plot without title

# %%
ggplot(data=mpg, mapping =aes(x=displ, y=hwy)) + 
geom_point()+
geom_line() + theme_bw()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x=displ,y= hwy,color = class))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=mpg,mapping = aes(x=displ,y=hwy,size = class))+ geom_point()
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x=displ,y = hwy, alpha = class)) + geom_point()
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot (data= mpg, mapping = aes(x = displ, y= hwy, shape = class)) + geom_point()
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data =mpg) +
geom_point(mapping =aes(x= displ, y=hwy))+ theme_bw()+
theme(axis.line = element_line(size=8, colour = "black"),
panel.grid.minor = element_blank(),
panel.border= element_blank(),
text= element_text(size=25))
# Out:
# plot without title

# %%
ggplot(data =mpg) + theme_bw()
geom_point(mapping =aes(x= displ, y=hwy))
+ facet_grid(drv~cyl)+
theme(axis.line = element_line(size=8, colour = "black"),
panel.grid.minor = element_blank(),
text= element_text(size=25))
# Out:
# mapping: x = ~displ, y = ~hwy
# geom_point: na.rm = FALSE
# stat_identity: na.rm = FALSE
# position_identity
# Error: Cannot use `+.gg()` with a single argument. Did you accidentally put + on a new line?
# Traceback:
#
# 1. `+.gg`(facet_grid(drv ~ cyl))
# 2. abort("Cannot use `+.gg()` with a single argument. Did you accidentally put + on a new line?")
# 3. signal_abort(cnd)
# plot without title
